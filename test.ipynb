# %% [markdown]
# # 작성법
# - 날짜는 제목2(샵2개)
# - 1장 2장은 제목1
# - 1절 2절은 제목3
# - 따로 번호는 안 붙지만 강조할 제목인 것 제목4
# - 질문은 Q 붙여서 제목2에 <font color=green>초록색</font> 답 필요한 건 ㅇㅇㅇㅇㅇ 붙여놓고 정답 찾으면 A.정답까지 초록색으로 남겨둠
# - cf.나는 문자열 기본으로 작은 따옴표 사용함

# %% [markdown]
# ## <font color=green>질문</font>

# %% [markdown]
# ㅇ 마크다운 문법
# - 색깔 <font color=blue|red|green|pink|yellow>텍스트(text)</font>

# %% [markdown]
# ㅇ 이미지 삽입
# - https://ssongblog.tistory.com/100
# - 마크다운으로 넣는 걸 추천 https://rlawjdghek.github.io/python%20memo/jupyter_image_insert/
# - 마크다운은 이미지 그냥 드래그 하면 돼
# - window+shift+s 로 이미지 따서 ctrl+v 해도 가능

# %%
# !pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\owner\anaconda3\lib\site-packages (7.19.0)
# Requirement already satisfied: pygments in c:\users\owner\anaconda3\lib\site-packages (from IPython) (2.7.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\owner\anaconda3\lib\site-packages (from IPython) (50.3.1.post20201107)
# Requirement already satisfied: jedi>=0.10 in c:\users\owner\anaconda3\lib\site-packages (from IPython) (0.17.1)
# Requirement already satisfied: decorator in c:\users\owner\anaconda3\lib\site-packages (from IPython) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\owner\anaconda3\lib\site-packages (from IPython) (3.0.8)
# Requirement already satisfied: backcall in c:\users\owner\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\owner\anaconda3\lib\site-packages (from IPython) (5.0.5)
# Requirement already satisfied: pickleshare in c:\users\owner\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\owner\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\owner\anaconda3\lib\site-packages (from jedi>=0.10->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\owner\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\owner\anaconda3\lib\site-packages (from traitlets>=4.2->IPython) (0.2.0)

# %%
from IPython.display import Image

# %%
test_img = Image('./images/nature-g72c7aa8a1_640.jpg')
test_img

# %% [markdown]
# ![nature-g72c7aa8a1_640.jpg](attachment:nature-g72c7aa8a1_640.jpg)

# %% [markdown]
# ## 8월 12일

# %% [markdown]
# # 1장 파이썬이란

# %%
1+1
# Out:
# 2

# %%
3/2.4
# Out:
# 1.25

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
a="python"
a
# Out:
# 'python'

# %%
a=3
if a>1 :
  print ("a is greater than 1")
# Out:
# a is greater than 1

# %%
for a in [1,2,3] :
  print(a)
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 3 :
  i = i+1
  print(i)
# Out:
# 1
# 2
# 3

# %%
def add(a, b):
  return a+b
  
add(3,4)
# Out:
# 7

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # 2장 자료형
# - 숫자형
# - 문자열
# - 리스트
# - 튜플
# - 딕셔너리
# - 집합
# - 불
# - 변수 : 자료형의 값을 저장하는 공간

# %% [markdown]
# ### 1. 숫자형

# %%
# 정수형
a = 123
# 실수형
b = 1.23

# %%
# 컴퓨터식 지수 표현 방식
c = 4.24E10                    # 4.24*10^10
d = 4.24E-10                   # 4.24*10^-10

# %%
# 8진수 : 숫자 0 알파벳 o(대소문자 상관 없음)
# 16진수 : 숫자 0 알파벳 x (근데 뒤에 8ff 처럼 알지 못하는 형식이 붙어..)

# %%
# 사칙연산
# +, -, *, / 은 그대로

# %%
# 제곱 **
e = 3
f = 4
e ** f
# Out:
# 81

# %%
# 나머지 %
7 % 3
# Out:
# 1

# %%
# 몫 //
7//3
# Out:
# 2

# %% [markdown]
# ### 2. 문자열 (총 4가지 = 2*2)
# - 큰 / 작은 : 서로의 안에 넣어줄 때 사용
# - 따옴표 1개 / 3개 : 문자열 내 줄바꿈 유무

# %% [markdown]
# ㅇ 왜 4가지나 되나?
# - 문자열 안에 따옴표가 들어가야 할 때 섞어서 사용하기 위해
# - 줄바꿈도 가능하게 하기 위해

# %%
g = "hello world"
h = 'hello world'
i = """Life is too short, You need python"""
k = '''Life is too short, You need python'''
g, h, i, k
# Out:
# ('hello world',
#  'hello world',
#  'Life is too short, You need python',
#  'Life is too short, You need python')

# %%
# 문자열 안에 작은 따옴표가 사용될 때 -> 큰 따옴표로 문자열 표현
food = "Python's favorite food is perl"
food
# Out:
# "Python's favorite food is perl"

# %%
# 만약 작은 따옴표를 사용한다면 열고 닫는 따옴표 갯수가 맞지 않아 syntax 에러가 나

# %%
# 같은 방식으로 큰 따옴표 사용하고 싶으면 -> 작은 따옴표로 문자열 표현

# %% [markdown]
# ㅇ 백슬래시
# - 문자열 안에 따옴표 넣는 또 다른 방법 : 백슬래시(\) 이용
# - 백슬래시 덕분에 문자 그 자체가 됨

# %%
food ='python\'s favorite food is perl'
food
# Out:
# "python's favorite food is perl"

# %% [markdown]
# ## 8월 13일

# %% [markdown]
# ㅇ 여러 줄인 문자열을 변수에 대입하고 싶을 때
# - 줄을 바꾸는 이스케이프 코드 '\n' 삽입하기
# - 따옴표 3개 사용

# %%
# 이스케이프코드
multiline = "Life is too short\nYou need python"
print(multiline)
# Out:
# Life is too short
# You need python

# %%
# 테스트
multiline
# Out:
# 'Life is too short\nYou need python'

# %%
# 연속 3개 따옴표 사용
multiline2 = '''Life is too short
You need python'''
print(multiline2)
multiline3 = """Life is too short
You need python"""
print(multiline3)
# Out:
# Life is too short
# You need python
# Life is too short
# You need python

# %% [markdown]
# ## <font color=green> Q.print 안 붙이고 그냥 multiline 만 적으면 저 형태 그대로 나옴 </font>
# ## <font color=green> 프린트와 그냥 변수 적는것의 차이는? ㅇㅇㅇㅇㅇ</font>

# %% [markdown]
# ㅇ 정리하면 따옴표를 이용한 문자열은
# - 문자열 내 따옴표 사용을 위해 큰/작은 둘 다 가능
# - 줄바꿈을 위해 3개 가능 (원래 1개)
#
# ㅇ 여기에 백슬래시를 이용한 방법도 각각 가능
# - 문자열 내 따옴표 사용은 그 따옴표 앞에 \
# - 줄바꿈은 원하는 곳에 \n 삽입
#
# cf. 책의 흐름이 이렇게 됐으면 깔끔했을텐데... 너무 물 흐르듯 을 중요시 여겼나? 구조화는 부족하네

# %% [markdown]
# #### ㅇ 이스케이프 코드
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### ㅇ 문자열 연산
# - 연결 : +
# - 반복 : *

# %%
# 더해서 연결
head = 'Python'
tail = ' is fun!'
head+tail
# Out:
# 'Python is fun!'

# %%
# 곱한 건 반복
a = 'python'
a*2
# Out:
# 'pythonpython'

# %%
# 곱하기 - 응용 - 절취선 만들기
# 여기서는 cmd 창 이용해서 py 파일 여는 것도 익힘

# %% [markdown]
# #### ㅇ 문자열 길이
# - len()

# %%
b = "Life is too short"   #빈칸도 셈
len(b)
# Out:
# 17

# %% [markdown]
# #### ㅇ 인덱싱 indexing
# - 가리킨다
# - 변수[인덱스번호]
# - 0부터 시작
# - 역으로 세면 음수

# %%
a = "Life is too short, You need python"
a[3]
# Out:
# 'e'

# %%
a[-6]
# Out:
# 'p'

# %% [markdown]
# #### ㅇ 슬라이싱 slicing
# - 잘라낸다
# - 변수[시작이상:끝미만]

# %%
a[0:4]
# Out:
# 'Life'

# %%
a[15:]
# Out:
# 'rt, You need python'

# %%
a[:]
# Out:
# 'Life is too short, You need python'

# %%
a[15:-7]
# Out:
# 'rt, You need'

# %% [markdown]
# ## <font color=green> Q. 만약 꼬이면 어떻게 될까? </font>
# ## <font color=green> A. 오류 나는 게 아니라 슬라이싱 되는 게 아무것도 없는 것! </font>

# %%
len(a)
# Out:
# 34

# %%
len(a)
a[33:-7]
# Out:
# ''

# %%
a[5:2]
# Out:
# ''

# %%
# 예제  - 문자열에서 날짜.날씨 나누기
a = '220813Rainy'
date = a[:6]
weather = a[6:]
print(date)
print(weather)
# Out:
# 220813
# Rainy

# %%
# 인덱싱 이용해서 오타 바꾸기 시도
a = 'pithon'
print(a)
a[1] = 'y'
pirnt(a)
# Out:
# pithon
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-0d567c5bb594> in <module>
#       2 a = 'pithon'
#       3 print(a)
# ----> 4 a[1] = 'y'
#       5 pirnt(a)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# - 문자열의 요솟값은 바꿀 수 있는 값이 아니기 때문에 (immutable한 자료형) 요솟값 변경 불가능
# - 이 방법 이용하려면 슬라이싱 사용해서 쪼개주고 -> 수정된 문자와 함께 다시 연결

# %%
a[:1]+'y'+a[2:]
# Out:
# 'python'

# %% [markdown]
# - 그렇다면 문자열의 요솟값 자유자재로 바꾸려면?

# %% [markdown]
# #### ㅇ 문자열 포매팅
# - 숫자 바로 대입 : %숫자
# - 문자열 바로 대입 : %문자
# - 숫자 값을 나타내는 변수로 대입 :
