# %% [markdown]
# # 마크다운 작성법
# - 날짜 : 제목3, 마젠타
# ###  <font color=magenta>8월 00일</font>
# - 절 : 제목1
# - 세부타이틀 : 제목2 예)ㅇ인덱싱
# - 서브내용타이틀 : 제목3 예)이스케이프 코드
# - 질문 : 제목2, 질문에 Q 답에는 A, 아직 답 못찾은 애는 ㅇㅇㅇㅇㅇ로 미완 표기
# ## <font color=green> Q. 질문 </font>
# - 나만의 주의 포인트, 내가 자주 실수하는 부분 : 제목2 빨간색
# ## <font color=red> 요거요거 주의하자! </font>

# %% [markdown]
# # 코드 나만의 기본값 - 최대한 범용적인 룰 쓰려 노력
# - 변수명 : 언더바 (스네이크 기법) 예) test_num
# - 문자열 : 작은 따옴표   ---> 근데 포매팅 들어가니까 안에 들어가는 애는 "" 쓰고 포매팅하는 큰 문자열은 ''쓰는 게 나은 듯?
# 그러면 기본으로는 큰 따옴표 쓸까?
# - 단어는 큰 따옴표, 문장은 작은 따옴표 이렇게 써볼까? 아냐 그래도 평소 한국어 상식이랑 통일되게
# 단어는 작은따옴표, 문장은 큰 따옴표 가자!
# - 포매팅 : format() 함수 사용

# %% [markdown]
# ## 이미지 삽입
# - 출처 : https://rlawjdghek.github.io/python%20memo/jupyter_image_insert/
# - 마크다운으로 넣는 걸 추천 : PIL과 겹칠 수 있어서
# - 마크다운은 이미지 그냥 드래그 해도 돼
# - window+shift+s 로 이미지 따서 ctrl+v 해도 가능

# %% [markdown]
# #### 일반 코드로 넣는 방법 (코드 맠다처리)
# !pip install IPython
# from IPython.display import Image
# test_img = Image('./images/nature-g72c7aa8a1_640.jpg')
# test_img

# %% [markdown]
# #### ㅇ 그냥 드래그해서 마크다운으로 넣음
# ![nature-g72c7aa8a1_640.jpg](attachment:nature-g72c7aa8a1_640.jpg)

# %% [markdown]
# ###  <font color=magenta>8월 12일</font>

# %% [markdown]
# # 1장 파이썬이란

# %%
1+1
# Out:
# 2

# %%
3/2.4
# Out:
# 1.25

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
a="python"
a
# Out:
# 'python'

# %%
a=3
if a>1 :
  print ("a is greater than 1")
# Out:
# a is greater than 1

# %%
for a in [1,2,3] :
  print(a)
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 3 :
  i = i+1
  print(i)
# Out:
# 1
# 2
# 3

# %%
def add(a, b):
  return a+b
  
add(3,4)
# Out:
# 7

# %%
print("hello world")
# Out:
# hello world
